# %%
tuple
l=(10,)
l=(10,20,"hello",10.6)
for i in l: 
    print(i)
# Out:
# 10
# 20
# hello
# 10.6

# %%
l=(10,20,"hello",10.6)     #index
print(l[1])
# Out:
# 20

# %%
l=(10,20,"hello",10.6)  #immutable
l(0)=100
print(l)
# Out:
#   Cell In[11], line 2
#     l(0)=100
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
l=(10,20,"hello",10.6)    #order
print(l)
# Out:
# (10, 20, 'hello', 10.6)

# %%
l=[1,5,3,4,5,1,6,7,7,5,9,11,5,8]
sum=0
for i in l:
    sum=i+sum
    mean=sum/len(l)
print(mean)
med=0
# Out:
# 5.5

# %%
l=[1,5,3,4,5,1,6,7,7,5,9,11,5,8]
sum=0
count=0
for i in l:
    sum=i+sum
    count=count+1
    mean=sum/count
print(mean)
sorted_list=sorted(l)
n=len(sorted_list)
if n%2!=0:
    median=sorted_list[n//2]
else:
    median=(sorted_list[n//2-1]+sorted_list[n//2])/2
print(int(median))
# Out:
# 5.5
# 5

# %%
l=[1,5,3,4,5,1,6,7,7,5,9,11,5,8]
sorted_list=sorted(l)
n=len(sorted_list)
print(sorted_list)
print(n)
# Out:
# [1, 1, 3, 4, 5, 5, 5, 5, 6, 7, 7, 8, 9, 11]
# 14

# %%
t=(10,20,30,100,10.5)
max_value=t[0]
for i in t:
    if i> max_value:
         max_value=i
print(max_value)




print(max(t))
print(min(t))
# Out:
# 100
# 100
# 10

# %%
t=(10,20,30,10.5,100)
l=list(t)
l.sort()
l.reverse()
t=tuple(l)
print(t)
print(tuple(sorted(t,reverse=True)))
# Out:
# (100, 30, 20, 10.5, 10)
# (100, 30, 20, 10.5, 10)
